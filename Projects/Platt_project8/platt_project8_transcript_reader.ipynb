# %%
""" 
    File Name: platt_project8_transcript_reader.py
    Author: Ben Platt
    Date: 11/08/22
    Course: COMP 1351
    Assignment: Project 8
    Collaborators: None
    Internet Source: None
"""

# %%
import os

# %%
def transcript_reader():
    path = "/Users/benplatt/Desktop/School/DU/COMP1351Autumn2022/COMP1351/Projects/Platt_project8"
    ext = ".txt"
    student_file = ''
    student_found = False
    while student_found == False:
        first_name = str(input('Please enter students first name (lowercase): '))
        last_name = str(input('Please enter students last name (lowercase): '))
        major_code = str(input('Please enter students major code: '))
        user_file_name = first_name + '_' + last_name + '.txt'

        for files in os.listdir(path):
            if files.endswith(ext):
                if files == user_file_name:
                    student_found = True
                    break
                else:
                    continue
    
    if student_found == True:
        student_dict = {}
        for i in range(len(content)):
            student_dict[i+1] = []
            with open('joe_shmo.txt') as f:
                content = f.readlines()
                content = [x.strip() for x in content]
                for x in range(len(content)):
                    student_dict[x+1] = content[x]

            for x in range(len(student_dict)):
                student_dict[x+1] = student_dict[x+1].split(",")
    
    print(str(first_name.capitalize()) + " " + str(last_name.capitalize()))
    print(major_code)

    credit_hours = 0
    for x in student_dict:
        student_dict[x][3] = float(student_dict[x][3])
    for z in student_dict:
        if student_dict[z][4] == 'F':
            continue
        else:
            credit_hours += student_dict[z][3]
    
    print('University Credit Hours:' + ' ' + str(credit_hours))

    gpa_list = []
    for a in student_dict:
        if student_dict[a][4] != 'T' or 'P':
            continue
        else:
            gpa_list.append(student_dict[a][4])
    
    gpa_list = []
    gpa = 0
    count = 0
    for a in student_dict:
        gpa_list.append(student_dict[a][4])

    for x in gpa_list:
        if x == 'A+':
            gpa += 4.0
            count += 1
        elif x == 'A':
            gpa += 4.0
            count += 1
        elif x == 'A-':
            gpa += 3.7
            count += 1
        elif x == 'B+':
            gpa += 3.3
            count += 1
        elif x == 'B':
            gpa += 3.0
            count += 1
        elif x == 'B-':
            gpa += 2.7
            count += 1
        elif x == 'C+':
            gpa += 2.3
            count += 1
        elif x == 'C':
            gpa += 2.0
            count += 1
        elif x == 'C-':
            gpa += 1.7
            count += 1
        elif x == 'D+':
            gpa += 1.3
            count += 1
        elif x == 'D':
            gpa += 1.0
            count += 1
        elif x == 'F':
            gpa += 0.0
            count += 1
    gpa = gpa / count
    
    print('GPA: ' + str(gpa))

# %%
student_dict = {}

with open('joe_shmo.txt') as f:
    content = f.readlines()
    content = [x.strip() for x in content]
    for i in range(len(content)):
        student_dict[i+1] = []
        for x in range(len(content)):
            student_dict[x+1] = content[x]

for x in range(len(student_dict)):
    student_dict[x+1] = student_dict[x+1].split(",")

for x in student_dict:
    student_dict[x][3] = float(student_dict[x][3])

credit_hours = 0
for z in student_dict:
    if student_dict[z][4] == 'F':
        continue
    else:
        credit_hours += student_dict[z][3]
#print(credit_hours)
gpa_list = []
gpa = 0
count = 0
for a in student_dict:
    gpa_list.append(student_dict[a][4])

for x in gpa_list:
    if x == 'A+':
        gpa += 4.0
        count += 1
    elif x == 'A':
        gpa += 4.0
        count += 1
    elif x == 'A-':
        gpa += 3.7
        count += 1
    elif x == 'B+':
        gpa += 3.3
        count += 1
    elif x == 'B':
        gpa += 3.0
        count += 1
    elif x == 'B-':
        gpa += 2.7
        count += 1
    elif x == 'C+':
        gpa += 2.3
        count += 1
    elif x == 'C':
        gpa += 2.0
        count += 1
    elif x == 'C-':
        gpa += 1.7
        count += 1
    elif x == 'D+':
        gpa += 1.3
        count += 1
    elif x == 'D':
        gpa += 1.0
        count += 1
    elif x == 'F':
        gpa += 0.0
        count += 1
gpa = gpa / count

print(gpa)
student_dict
# Out:
# 2.814285714285714
# {1: ['COMN', '1012', 'Speaking on Ideas that Matter', 4.0, 'A'],
#  2: ['MATH', '1951', 'Calculus I', 4.0, 'A'],
#  3: ['PSYC', '1001', 'Intro Psychology', 4.5, 'T'],
#  4: ['SOCI', '2420', 'Social Inequality', 4.0, 'P'],
#  5: ['WRIT', '1122', 'Rhetoric and Academic Writing', 4.0, 'P'],
#  6: ['ANTH', '1010', 'Humankind in Context', 4.0, 'P'],
#  7: ['COMP', '1201', 'Introduction to Computer Science', 2.0, 'A-'],
#  8: ['COMP', '1351', 'Introduction to Programming I', 3.0, 'B+'],
#  9: ['MATH', '1952', 'Calculus II', 4.0, 'C'],
#  10: ['PSYC', '2031', 'Introduction to Cognitive Neuroscience', 4.0, 'B-'],
#  11: ['EDPX', '2000', 'Imaging in Emergent Digital Practices', 4.0, 'F'],
#  12: ['COMP', '2300', 'Discrete Structures in Computer Science', 4.0, 'P']}

# %%
gpa = 0
count = 0

for x in gpa_list:
    if x == 'A':
        gpa += 4.0
        count += 1
    elif x == 'A+':
        gpa += 4.0
        count += 1
    elif x == 'A-':
        gpa += 3.7
        count += 1
    elif x == 'B+':
        gpa += 3.3
        count += 1
    elif x == 'B-':
        gpa += 2.7
        count += 1
    elif x == 'C+':
        gpa += 2.3
        count += 1
    elif x == 'C':
        gpa += 2.0
        count += 1
    elif x == 'C-':
        gpa += 1.7
        count += 1
    elif x == 'D+':
        gpa += 1.3
        count += 1
    elif x == 'D':
        gpa += 1.0
        count += 1
    elif x == 'F':
        gpa += 0
        count += 1
gpa = gpa / count
print(gpa)
# Out:
# 2.814285714285714
