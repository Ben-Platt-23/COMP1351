# %%
def question_3():
    user_number = int(input("Please enter an integer from 1 to 100: "))

    while user_number > 100 or user_number < 1:
        user_number = int(input('Invalid entry! Please enter an integer from 1 to 100: '))
        if user_number >= 1 and user_number <= 100:
            break
    
    if user_number % 2 == 0:
        print('Your number is even!')
    else:
        print('Your number is odd!')

# %%
# question_3()

# %%
# import dudraw

# %%
# def question_4():
    
    
#     # dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     # dudraw.set_pen_width(1)
#     # # Gray
#     # dudraw.filled_circle(50, 450, 25)

#     # # Red circles
#     # dudraw.set_pen_color(dudraw.RED)
#     # dudraw.set_pen_width(1)
#     # # Top red circle
#     # dudraw.filled_circle(50, 488, 11.75)
#     # # Left red circle 
#     # dudraw.filled_circle(12, 450, 11.75)
#     # # Right red circle 
#     # dudraw.filled_circle(88, 450, 11.75)
#     # # Bottom red circle 
#     # dudraw.filled_circle(50, 412, 11.75)


#     # Constants
#     gr = 25
#     rr = 11.75


#     gx = 50
#     gy = 450

#     rxL = 12
#     ryL = 450

#     rxR = 88
#     ryR = 450

#     rxT = 50
#     ryT = 488

#     rxB = 50
#     ryB = 412

#     count = 0

#     for j in range(36):
#         if count == 6:
#             count = 0
#             gy -= 75
#             ryL -= 75
#             ryR -= 75
#             ryT -= 75
#             ryB -= 75

#         # Main grey circle 
#         dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#         dudraw.filled_circle(gx, gy, gr)
#         # Four smaller red circles 
#         dudraw.set_pen_color(dudraw.RED)
#         # Left 
#         dudraw.filled_circle(rxL, ryL, rr)
#         # Right
#         dudraw.filled_circle(rxR, ryR, rr)
#         # Top
#         dudraw.filled_circle(rxT, ryT, rr)
#         # Bottom
#         dudraw.filled_circle(rxB, ryB, rr)

#         count += 1
#         print(count)
        

        

#     dudraw.show()
# #question_4()

# %%
# def question_4():
#     dudraw.set_canvas_size(600, 500)
#     dudraw.clear(dudraw.WHITE)
#     dudraw.set_x_scale(0, 600)
#     dudraw.set_y_scale(0, 500)

#     # Constants
#     gr = 25
#     rr = 11.75

#     gx = 50
#     gy = 450

#     rxL = 12
#     ryL = 450

#     rxR = 88
#     ryR = 450

#     rxT = 50
#     ryT = 488

#     rxB = 50
#     ryB = 412

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

# # Row 2
#     gy = 375
#     ryL = 375
#     ryR = 375
#     ryT = 413
#     ryB = 337

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100

#     # Main grey circle 
#     dudraw.set_pen_color(dudraw.LIGHT_GRAY)
#     dudraw.filled_circle(gx, gy, gr)
#     # Four smaller red circles 
#     dudraw.set_pen_color(dudraw.RED)
#     # Left 
#     dudraw.filled_circle(rxL, ryL, rr)
#     # Right
#     dudraw.filled_circle(rxR, ryR, rr)
#     # Top
#     dudraw.filled_circle(rxT, ryT, rr)
#     # Bottom
#     dudraw.filled_circle(rxB, ryB, rr)
#     gx += 100
#     rxL += 100
#     rxR += 100
#     rxT += 100
#     rxB += 100




    

#     dudraw.show()

# #question_4()

# %%
# dudraw.set_canvas_size(600, 600)
# dudraw.clear(dudraw.GREEN)
# dudraw.set_x_scale(0, 600)
# dudraw.set_y_scale(0, 600)

# # Constants
# gr = 25
# rr = 11.75

# # Row 1
# # Col 1
# gx = 50
# gy = 550

# rxL = 12
# ryL = 550

# rxR = 88
# ryR = 550

# rxT = 50
# ryT = 588

# rxB = 50
# ryB = 512
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 2
# # Col 1
# gx = 50
# gy = 450

# rxL = 12
# ryL = 450

# rxR = 88
# ryR = 450

# rxT = 50
# ryT = 488

# rxB = 50
# ryB = 412
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 3
# # Col 1
# gx = 50
# gy = 350

# rxL = 12
# ryL = 350

# rxR = 88
# ryR = 350

# rxT = 50
# ryT = 388

# rxB = 50
# ryB = 312
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 4
# # Col 1
# gx = 50
# gy = 250

# rxL = 12
# ryL = 250

# rxR = 88
# ryR = 250

# rxT = 50
# ryT = 288

# rxB = 50
# ryB = 212
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 5
# # Col 1
# gx = 50
# gy = 150

# rxL = 12
# ryL = 150

# rxR = 88
# ryR = 150

# rxT = 50
# ryT = 188

# rxB = 50
# ryB = 112
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 6
# # Col 1
# gx = 50
# gy = 50

# rxL = 12
# ryL = 50

# rxR = 88
# ryR = 50

# rxT = 50
# ryT = 88

# rxB = 50
# ryB = 12
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)



# # Row 1
# # Col 2
# gx = 50 + 100
# gy = 550

# rxL = 12 + 100
# ryL = 550

# rxR = 88 + 100
# ryR = 550

# rxT = 50 + 100
# ryT = 588

# rxB = 50 + 100
# ryB = 512
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 2
# # Col 2
# gx = 50 + 100
# gy = 450

# rxL = 12 + 100
# ryL = 450

# rxR = 88 + 100
# ryR = 450

# rxT = 50 + 100
# ryT = 488

# rxB = 50 + 100
# ryB = 412
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 3
# # Col 2
# gx = 50 + 100
# gy = 350

# rxL = 12 + 100
# ryL = 350

# rxR = 88 + 100
# ryR = 350

# rxT = 50 + 100
# ryT = 388

# rxB = 50 + 100
# ryB = 312
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 4
# # Col 2
# gx = 50 + 100
# gy = 250

# rxL = 12 + 100
# ryL = 250

# rxR = 88 + 100
# ryR = 250

# rxT = 50 + 100
# ryT = 288

# rxB = 50 + 100
# ryB = 212
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 5
# # Col 2
# gx = 50 + 100
# gy = 150

# rxL = 12 + 100
# ryL = 150

# rxR = 88 + 100
# ryR = 150

# rxT = 50 + 100
# ryT = 188

# rxB = 50 + 100
# ryB = 112
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 6
# # Col 2
# gx = 50 + 100
# gy = 50

# rxL = 12 + 100
# ryL = 50

# rxR = 88 + 100
# ryR = 50

# rxT = 50 + 100
# ryT = 88

# rxB = 50 + 100
# ryB = 12
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)


# # Row 1
# # Col 3
# gx = 50 + 200
# gy = 550

# rxL = 12 + 200
# ryL = 550

# rxR = 88 + 200
# ryR = 550

# rxT = 50 + 200
# ryT = 588

# rxB = 50 + 200
# ryB = 512
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 2
# # Col 3
# gx = 50 + 200
# gy = 450

# rxL = 12 + 200
# ryL = 450

# rxR = 88 + 200
# ryR = 450

# rxT = 50 + 200
# ryT = 488

# rxB = 50 + 200
# ryB = 412
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 3
# # Col 3
# gx = 50 + 200
# gy = 350

# rxL = 12 + 200
# ryL = 350

# rxR = 88 + 200
# ryR = 350

# rxT = 50 + 200
# ryT = 388

# rxB = 50 + 200
# ryB = 312
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 4
# # Col 3
# gx = 50 + 200
# gy = 250

# rxL = 12 + 200
# ryL = 250

# rxR = 88 + 200
# ryR = 250

# rxT = 50 + 200
# ryT = 288

# rxB = 50 + 200
# ryB = 212
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 5
# # Col 3
# gx = 50 + 200
# gy = 150

# rxL = 12 + 200
# ryL = 150

# rxR = 88 + 200
# ryR = 150

# rxT = 50 + 200
# ryT = 188

# rxB = 50 + 200
# ryB = 112
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 6
# # Col 3
# gx = 50 + 200
# gy = 50

# rxL = 12 + 200
# ryL = 50

# rxR = 88 + 200
# ryR = 50

# rxT = 50 + 200
# ryT = 88

# rxB = 50 + 200
# ryB = 12
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)



# # Row 1
# # Col 4
# gx = 50 + 300
# gy = 550

# rxL = 12 + 300
# ryL = 550

# rxR = 88 + 300
# ryR = 550

# rxT = 50 + 300
# ryT = 588

# rxB = 50 + 300
# ryB = 512
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 2
# # Col 4
# gx = 50 + 300
# gy = 450

# rxL = 12 + 300
# ryL = 450

# rxR = 88 + 300
# ryR = 450

# rxT = 50 + 300
# ryT = 488

# rxB = 50 + 300
# ryB = 412
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 3
# # Col 4
# gx = 50 + 300
# gy = 350

# rxL = 12 + 300
# ryL = 350

# rxR = 88 + 300
# ryR = 350

# rxT = 50 + 300
# ryT = 388

# rxB = 50 + 300
# ryB = 312
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 4
# # Col 4
# gx = 50 + 300
# gy = 250

# rxL = 12 + 300
# ryL = 250

# rxR = 88 + 300
# ryR = 250

# rxT = 50 + 300
# ryT = 288

# rxB = 50 + 300
# ryB = 212
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 5
# # Col 4
# gx = 50 + 300
# gy = 150

# rxL = 12 + 300
# ryL = 150

# rxR = 88 + 300
# ryR = 150

# rxT = 50 + 300
# ryT = 188

# rxB = 50 + 300
# ryB = 112
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 6
# # Col 4
# gx = 50 + 300
# gy = 50

# rxL = 12 + 300
# ryL = 50

# rxR = 88 + 300
# ryR = 50

# rxT = 50 + 300
# ryT = 88

# rxB = 50 + 300
# ryB = 12
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)



# # Row 1
# # Col 5
# gx = 50 + 400
# gy = 550

# rxL = 12 + 400
# ryL = 550

# rxR = 88 + 400
# ryR = 550

# rxT = 50 + 400
# ryT = 588

# rxB = 50 + 400
# ryB = 512
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 2
# # Col 5
# gx = 50 + 400
# gy = 450

# rxL = 12 + 400
# ryL = 450

# rxR = 88 + 400
# ryR = 450

# rxT = 50 + 400
# ryT = 488

# rxB = 50 + 400
# ryB = 412
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 3
# # Col 5
# gx = 50 + 400
# gy = 350

# rxL = 12 + 400
# ryL = 350

# rxR = 88 + 400
# ryR = 350

# rxT = 50 + 400
# ryT = 388

# rxB = 50 + 400
# ryB = 312
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 4
# # Col 5
# gx = 50 + 400
# gy = 250

# rxL = 12 + 400
# ryL = 250

# rxR = 88 + 400
# ryR = 250

# rxT = 50 + 400
# ryT = 288

# rxB = 50 + 400
# ryB = 212
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 5
# # Col 5
# gx = 50 + 400
# gy = 150

# rxL = 12 + 400
# ryL = 150

# rxR = 88 + 400
# ryR = 150

# rxT = 50 + 400
# ryT = 188

# rxB = 50 + 400
# ryB = 112
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 6
# # Col 5
# gx = 50 + 400
# gy = 50

# rxL = 12 + 400
# ryL = 50

# rxR = 88 + 400
# ryR = 50

# rxT = 50 + 400
# ryT = 88

# rxB = 50 + 400
# ryB = 12
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)



# # Row 1
# # Col 6
# gx = 50 + 500
# gy = 550

# rxL = 12 + 500
# ryL = 550

# rxR = 88 + 500
# ryR = 550

# rxT = 50 + 500
# ryT = 588

# rxB = 50 + 500
# ryB = 512
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 2
# # Col 6
# gx = 50 + 500
# gy = 450

# rxL = 12 + 500
# ryL = 450

# rxR = 88 + 500
# ryR = 450

# rxT = 50 + 500
# ryT = 488

# rxB = 50 + 500
# ryB = 412
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 3
# # Col 6
# gx = 50 + 500
# gy = 350

# rxL = 12 + 500
# ryL = 350

# rxR = 88 + 500
# ryR = 350

# rxT = 50 + 500
# ryT = 388

# rxB = 50 + 500
# ryB = 312
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 4
# # Col 6
# gx = 50 + 500
# gy = 250

# rxL = 12 + 500
# ryL = 250

# rxR = 88 + 500
# ryR = 250

# rxT = 50 + 500
# ryT = 288

# rxB = 50 + 500
# ryB = 212
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 5
# # Col 6
# gx = 50 + 500
# gy = 150

# rxL = 12 + 500
# ryL = 150

# rxR = 88 + 500
# ryR = 150

# rxT = 50 + 500
# ryT = 188

# rxB = 50 + 500
# ryB = 112
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)

# # Row 6
# # Col 6
# gx = 50 + 500
# gy = 50

# rxL = 12 + 500
# ryL = 50

# rxR = 88 + 500
# ryR = 50

# rxT = 50 + 500
# ryT = 88

# rxB = 50 + 500
# ryB = 12
# # Main grey circle 
# dudraw.set_pen_color(dudraw.LIGHT_GRAY)
# dudraw.filled_circle(gx, gy, gr)
# # Four smaller red circles 
# dudraw.set_pen_color(dudraw.RED)
# # Left 
# dudraw.filled_circle(rxL, ryL, rr)
# # Right
# dudraw.filled_circle(rxR, ryR, rr)
# # Top
# dudraw.filled_circle(rxT, ryT, rr)
# # Bottom
# dudraw.filled_circle(rxB, ryB, rr)








# dudraw.show()

# %%
import dudraw

# def question_5():

dudraw.set_canvas_size(625, 525)
dudraw.clear(dudraw.BLACK)
dudraw.set_x_scale(0, 625)
dudraw.set_y_scale(0, 525)


def draw_car(x: float, y: float, w: float, h: float)->None:
    """
    Draw a little blue VW beetle car. (x,y) is the lower left-hand
    corner, while w and h give the width and height of the car.
    """

    if w > 1:
        w = w / 10
    if h > 1:
        h = h / 60

    dudraw.set_pen_color_rgb(142,199,217) # blue body of car
    dudraw.filled_elliptical_sector(x+w/2, y+h*0.1, w/2, h*0.6, 0, 180)
    dudraw.filled_elliptical_sector(x+w/2, y+h*0.5, w/3, h*0.5, 0, 180)
    dudraw.set_pen_color(dudraw.WHITE)
    dudraw.filled_elliptical_sector(x+w*0.55, y+h*0.58, w*0.25, h*0.35, 0, 90 )
    dudraw.set_pen_color(dudraw.DARK_GRAY) # dark gray outline for the car window
    dudraw.elliptical_sector(x+w*0.55, y+h*0.58, w*0.25, h*0.35, 0, 90 )
    dudraw.set_pen_color(dudraw.WHITE) # white for the wheels
    dudraw.filled_ellipse(x+w*0.15, y+h*0.1, w*0.1, h*0.1)
    dudraw.filled_ellipse(x+w*0.85, y+h*0.1, w*0.1, h*0.1)
    dudraw.set_pen_color(dudraw.BLACK) # black outline of wheels
    dudraw.ellipse(x+w*0.15, y + h*0.1, w*0.1, h*0.1)
    dudraw.ellipse(x+w*0.85, y + h*0.1, w*0.1, h*0.1)

x = 750
y = 3000


# Row 1
draw_car(10, 470, x, y)
draw_car(85, 470, x, y)
draw_car(160, 470, x, y)
draw_car(235, 470, x, y)
draw_car(310, 470, x, y)
draw_car(385, 470, x, y)
draw_car(460, 470, x, y)
draw_car(535, 470, x, y)

# Row 2
draw_car(10, 400, x, y)
draw_car(85, 400, x, y)
draw_car(160, 400, x, y)
draw_car(235, 400, x, y)
draw_car(310, 400, x, y)
draw_car(385, 400, x, y)
draw_car(460, 400, x, y)

# Row 3
draw_car(10, 330, x, y)
draw_car(85, 330, x, y)
draw_car(160, 330, x, y)
draw_car(235, 330, x, y)
draw_car(310, 330, x, y)
draw_car(385, 330, x, y)

# Row 4
draw_car(10, 270, x, y)
draw_car(85, 270, x, y)
draw_car(160, 270, x, y)
draw_car(235, 270, x, y)
draw_car(310, 270, x, y)

# Row 5
draw_car(10, 200, x, y)
draw_car(85, 200, x, y)
draw_car(160, 200, x, y)
draw_car(235, 200, x, y)

# Row 6
draw_car(10, 130, x, y)
draw_car(85, 130, x, y)
draw_car(160, 130, x, y)

# Row 7
draw_car(10, 70, x, y)
draw_car(85, 70, x, y)

# Row 1
draw_car(10, 10, x, y)

dudraw.show()

# %%
def largerThan(x: int, y: int) :
    answer = False
    if x > y :
        answer = True
    else :
        answer = False
    return answer

for b in range(1,3) :
    for k in range(0,4) :
        print(f'Is {b} larger than {k}? {largerThan(b,k)}')
# Out:
# Is 1 larger than 0? True
# Is 1 larger than 1? False
# Is 1 larger than 2? False
# Is 1 larger than 3? False
# Is 2 larger than 0? True
# Is 2 larger than 1? True
# Is 2 larger than 2? False
# Is 2 larger than 3? False
